# %% [markdown]
# ## Hypothesis
# Caching repeated deterministic calculations should reduce repeated-run latency. This is a testable hypothesis, not a measured result.

# %%
from functools import lru_cache
@lru_cache(maxsize=128)
def square(n):
    return n * n
assert square(12) == 144

# %% [markdown]
# This private scratch cell is deliberately excluded from the memory plan.
